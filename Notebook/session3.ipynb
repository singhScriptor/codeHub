// %%
let rotateArray=function(nums,k){
    k=k%nums.length
    let rotated=nums.slice(-k).concat(nums.slice(0,-k))
    for(let i=0;i<nums.length;i++){
        nums[i]=rotated[i]
    }
    return nums
}
let  nums = [1,2,3,4,5,6,7], k = 3
console.log(rotateArray(nums,k))
// Out:
// [
//   5, 6, 7, 1,
//   2, 3, 4
// ]

// %%
let binarySearch=function(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid]===target)return mid
        else if(nums[mid]>target)right=mid-1
        else left=mid+1
    }
    return -1
}
let nums = [-1,0,3,5,9,12], target = 9
console.log(binarySearch(nums,target))
// Out:
// 4

// %%
let twoSum=function(nums,target){
    for(let i=0;i<nums.length;i++){
        for(let j=i+1;j<nums.length;j++){
            if(nums[i]+nums[j]===target)return [i,j]
        }
    }
    return [-1,-1]
}
let nums = [2,7,11,15], target = 9
console.log(twoSum(nums,target))
// Out:
// [ 0, 1 ]

// %%
let findLuckyInt=function(arr){
    let set=new Set(arr),maxi=-1
    for(let i of set){
        let index=arr.filter(sh=>sh===i).length
        if(index === i){
            maxi=Math.max(maxi,i)
        }
    }
    return maxi
}
let arr = [2,2,3,4]
console.log(findLuckyInt(arr))
// Out:
// 2

// %%
let countPrime=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime.filter(prime=>prime).length
}
let n=10
console.log(countPrime(n))
// Out:
// 4

// %%
let richestCustomer=function(accounts){
    let maxi=-Infinity
    for(let i=0;i<accounts.length;i++){
        let total=accounts[i].reduce((a,b)=>a+b,0)
        maxi=Math.max(maxi,total)
    }
    return maxi
}
let accounts = [[1,2,3],[3,2,1]]
console.log(richestCustomer(accounts))
// Out:
// 6

// %%
let validateStackSeq=function(pushed,popped){
    let stack=[]
    for(let i of pushed){
        stack.push(i)
        while(stack.length && stack[stack.length-1]===popped[0]){
            popped.shift()
            stack.pop()
        }
    }
    return stack.length === 0
}
let pushed = [1,2,3,4,5], popped = [4,5,3,2,1]
console.log(validateStackSeq(pushed,popped))
// Out:
// true

// %%
let removeAllAdjacentDUplicate=function(s){
    let stack=[]
    for(let i of s){
        if(stack.length && stack[stack.length-1]===i)stack.pop()
        else stack.push(i)    
    }
    return stack.join('')
}
let s = "abbaca"
console.log(removeAllAdjacentDUplicate(s))
// Out:
// ca

// %%
let decodeString=function(s){
    let str='',num=0,stack=[]
    for(let i  of s){
        if(!isNaN(i))num=num*10+parseInt(i)
        else if(i === '['){
            stack.push(str)
            stack.push(num)
            str=''
            num=0
        }
        else if(i === ']'){
            let prevNum=stack.pop()
            let preStr=stack.pop()
            str=preStr+str.repeat(prevNum)
        }
        else str+=i
    }
    return str
}
let  s = "3[a]2[bc]"
console.log(decodeString(s))
// Out:
// aaabcbc

// %%
let nxtGreaterElement=function(nums){
    let arr=new Array(nums.length)
    for(let i=0;i<nums.length;i++){
        arr[i]=-1
        for(let j=1;j<nums.length;j++){
            let index=(i+j)%nums.length
            if(nums[index]>nums[i]){
                arr[i]=nums[index]
                break
            }
        }
    }
    return arr
}
let nums = [1,2,1]
console.log(nxtGreaterElement(nums))
// Out:
// [ 2, -1, 2 ]

// %%
let trappingRainWater=function(height){
    let l=0,h=height.length-1
    let lMax=height[l],hMax=height[h],ans=0
    while(l<h){
        if(lMax < hMax){
            l++
            lMax=Math.max(lMax,height[l])
            ans+=lMax-height[l]
        }
        else{
            h--
            hMax=Math.max(hMax,height[h])
            ans+=hMax-height[h]
        }
    }
    return ans
}
let height = [0,1,0,2,1,0,1,3,2,1,2,1]
console.log(trappingRainWater(height))
// Out:
// 6

// %%
let onlineStockSpan=function(){
    this.stack=[]
}
onlineStockSpan.prototype.next=function(price){
    let span=1
    while(this.stack.length && this.stack[this.stack.length-1].price < price){
        span+=this.stack.pop().span
    }
    this.stack.push({price,span})
    return span
}

// %%
let rectHistoGram=function(heights){
    heights.push(0)
    let maxi=0,stack=[-1]
    for(let i=0; i<heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
    }
    return maxi
}
let  heights = [2,1,5,6,2,3]
console.log(rectHistoGram(heights))
// Out:
// 10

// %%
let maximumSlidingwindow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]<nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i>=k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(maximumSlidingwindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let validateParentheses=function(s){
     let dict={']':'[','}':'{',')':'('},stack=[]
     for(let i of s){
        if(i in dict){
            if(stack.length === 0 || stack.pop()!==dict[i])return false
        }
        else stack.push(i)
     }
     return stack.length===0
}
let s="{}"
console.log(validateParentheses(s))
// Out:
// false

// %%
let nonRepeatChar=function(s){
    let freq=new Array(26).fill(0)
    let stack=[],res=''
    for(let i of s){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            res+=stack[0]
        }
        else{
            res+='#'
        }
    }
    return res
}
let s="abadbc"
console.log(nonRepeatChar(s))
// Out:
// aabbdd

// %%
let nonRepeatChar2=function(A){
    let freq=new Array(26).fill(0)
    let stack=[],ans=''
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            ans+=stack[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let s="abadbc"
console.log(nonRepeatChar2(s))
// Out:
// aabbdd

// %%
let nonRepChar=function(A){
    let freq=new Array(26).fill(0)
    let stack=[],ans=''
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            ans+=stack[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let s="abadbc"
console.log(nonRepChar(s))
// Out:
// aabbdd

// %%
let bubbleSort=function(arr){
    for(let i=0;i<arr.length-1;i++){
        for(let j=0;j<nums.length-1-i;j++){
            if(arr[j] > arr[j+1]){
                let temp=arr[j]
                arr[j]=arr[j+1]
                arr[j+1]=temp
            }
        }
    }
    return arr
}
let arr=[5,1,3,4,2]
console.log(bubbleSort(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let insertionSort=function(arr){
    for(let i=0;i<arr.length;i++){
        let temp=arr[i]
        let j=i-1
        while(j>=0 && arr[j] > temp){
            arr[j+1]=arr[j]
            j--
        }
        arr[j+1]=temp
    }
    return arr
}
let arr=[4,1,5,3,2]
console.log(insertionSort(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let insertion2=function(arr){
    for(let i=0;i<arr.length;i++){
        let temp=arr[i]
        let j=i-1
        while(j>=0 && arr[j] > temp){
            arr[j+1]=arr[j]
            j--
        }
        arr[j+1]=temp
    }
    return arr
}
let arr=[4,1,5,3,2]
console.log(insertion2(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let selectionSort=function(arr){
    for(let i=0;i<arr.length;i++){
        let temp=i 
        for(let j=i+1;j<arr.length;j++){
            if(arr[j] < arr[temp]){
                temp=j
            }
        }
        let ans=arr[i]
        arr[i]=arr[temp]
        arr[temp]=ans
    }
    return arr
}
let arr=[5,1,2,4,3]
console.log(selectionSort(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let selectionSort=function(arr){
    for(let i=0;i<arr.length;i++){
        let temp=i 
        for(let j=i+1;j<arr.length;j++){
            if(arr[j] < arr[temp]){
                temp=j
            }
        }
        let ans=arr[i]
        arr[i]=arr[temp]
        arr[temp]=ans
    }
    return arr
}
let arr=[5,1,2,4,3]
console.log(selectionSort(arr))
// Out:
// [ 5, 4, 3, 2, 1 ]

// %%
let palindrome=function(s){
    s=s.toLowerCase().replace(/[^a-z0-9]/g,'')
    for(let i=0;i<s.length/2;i++){
        if(s[i] !== s[s.length-1-i])return false
    }
    return true
}
let s='Madams'
console.log(palindrome(s))
// Out:
// false

// %%
let nonRepeatChar=function(A){
    let freq=new Array(26).fill(0)
    let str='',stack=[]
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            str+=stack[0]
        }
        else{
            str+='#'
        }
    }
    return str
}
let s="abadbc"
console.log(nonRepeatChar(s))
// Out:
// aabbdd

// %%
var number1=2
var number2=5
function multiply(a,b){
    var answer=a*b  // line 1
    return answer
}
var sum=multiply(number1,number2) // line 2
console.log(sum) // line 3
console.log(answer) // line 4
// Out:
// 10
// Stack trace:
// ReferenceError: answer is not defined
//     at <anonymous>:11:13

// %%
var a=3
var c=3
function b(){
    var x=3
    var c=5
    console.log(c)
}
console.log(a)
console.log(this.a)
console.log(this.c)
console.log(this.x)
console.log(window.a)
console.log(window.x)
console.log(b())
// Out:
// 3
// 3
// 3
// undefined
// 5
// undefined

// %%
function abc(){
    console.log(a)
}
var  a=11 // in the start it will be undefined
abc() // this will call first and inside abc there is no value inside the block scope so it will call from global scope
// Out:
// 11

// %%
let a=50
{
    var a=30
    let b=20
    let c=30
}
console.log(a)
// Out:
// Stack trace:
// SyntaxError: Identifier 'a' has already been declared

// %%
const a = 10;

{

const a = 20;

{

const a = 50;

console.log(a);

}

console.log(a)

}

console.log(a)
// Out:
// Stack trace:
// SyntaxError: Identifier 'a' has already been declared

// %%
class Student{
    constructor(name,age,marks){
        this.name=name
        this.age=age
        this.marks=marks
    }
    setPlaceMentAge(minPlacementAge){
        return (minMarks)=>{
            return this.age >= minPlacementAge && this.marks >= minMarks
        }
    }
}

// %%
let findName=function(obj,age){
    for(let i in obj){
        if(i===age){
            return i
        }
    }
    return -1
}
let studentobj = {
    'yash': 26,
    'vaibhav': 24,
    'rajesh' : 25,

}
let age=25
console.log(findName(studentobj,age))
// Out:
// -1

// %%
let validParentheses=function(s){
    let dict={']':'[','}':'{',')':'('}
    let stack=[]
    for(let i of s){
        if(i in dict){
            if(stack.length === 0 || stack.pop() !== dict[i])return false
        }
        else stack.push(i)
    }
    return stack.length === 0
}
let s="{}"
console.log(validParentheses(s))
// Out:
// false

// %%
let slidingWindow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]<nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i >= k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let  nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(slidingWindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let largestRectHisto=function(heights){
    heights.push(0)
    let maxi=0,stack=[-1]
    for(let i=0; i<=heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
    }
    return maxi
}
let heights=[2,1,5,6,2,3]
console.log(largestRectHisto(heights))
// Out:
// 10

// %%
let largestRectHisto2=function(heights){
    heights.push(0)
    let maxi=0,stack=[-1]
    for(let i=0;i<heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
    }
    return maxi
}
let heights=[2,1,5,6,2,3]
console.log(largestRectHisto2(heights))
// Out:
// 10

// %%
let onlineStockSpan=function(){
    this.stack=[]
}
onlineStockSpan.prototype.next=function(price){
    let span=1
    while(this.stack && this.stack[this.stack.length-1].price < price){
        span+=this.stack.pop().span
    }
    this.stack.push({price,span})
    return span
}

// %%
let trappingRainWater=function(heights){
    let left=0,right=heights.length-1,
    leftMax=heights[left],rightMax=heights[right],
    ans=0
    while(left < right){
        if(leftMax < rightMax){
            left++
            leftMax=Math.max(leftMax,heights[left])
            ans+=leftMax-heights[left]
        }
        else{
            right--
            rightMax=Math.max(rightMax,heights[right])
            ans+=rightMax-heights[right]
        }
    }
    return ans
}
let height = [0,1,0,2,1,0,1,3,2,1,2,1]
console.log(trappingRainWater(height))
// Out:
// 6

// %%
let nextGreaterElement=function(nums){
    let arr=new Array(nums.length)
    for(let i=0;i<nums.length;i++){
        arr[i]=-1
        for(let j=1;j<nums.length;j++){
            let index=(i+j)%nums.length
            if(nums[index] > nums[i]){
                arr[i]=nums[index]
                break
            }
        }
    }
    return arr 
}
let nums=[1,2,1]
console.log(nextGreaterElement(nums))
// Out:
// [ 2, -1, 2 ]

// %%
let nextGrtElement2=function(nums){
    let arr=new Array(nums.length)
    for(let i=0;i<nums.length;i++){
        arr[i]=-1
        for(let j=1;j<nums.length;j++){
            let index=(i+j)%nums.length
            if(nums[index] > nums[i]){
                arr[i]=nums[index]
                break
            }
        }
    }
    return arr
}
let nums=[1,2,1]
console.log(nextGrtElement2(nums))
// Out:
// [ 2, -1, 2 ]

// %%
let decodeString=function(s){
    let str='',num=0,stack=[]
    for(let i of s){
        if(!isNaN(i)){
            num=num*10+parseInt(i)
        }
        else if(i==='['){
            stack.push(str)
            stack.push(num)
            str=''
            num=0
        }
        else if(i === ']'){
            let prevNum=stack.pop()
            let prevStr=stack.pop()
            str=prevStr+str.repeat(prevNum)
        }
        else{
            str+=i 
        }
    }
    return str
}
let s="3[a]2[bc]"
console.log(decodeString(s))
// Out:
// aaabcbc

// %%
let removeAllAdjacant=function(s){
    let stack=[]
    for(let i of s){
        if(stack.length && stack[stack.length-1] === i){
            stack.pop()
        }
        else stack.push(i)
    }
    return stack.join('')
}
let s="abbaca"
console.log(removeAllAdjacant(s))
// Out:
// ca

// %%
let removeAllAdjacant=function(s){
    let stack=[]
    for(let i of s){
        if(stack.length && stack[stack.length-1] === i)stack.pop()
        else stack.push(i)
    }
    return stack.join('')
}
let s="abbaca"
console.log(removeAllAdjacant(s))
// Out:
// ca

// %%
let validateStackSeq=function(pushed,popped){
    let stack=[]
    for(let i of pushed){
        stack.push(i)
        while(stack.length && stack[stack.length-1] === popped[0]){
            
            stack.pop()
            popped.shift()
        }
    }
    return stack.length === 0
}
let pushed=[1,2,3,4,5],popped=[4,5,3,2,1]
console.log(validateStackSeq(pushed,popped))
// Out:
// true

// %%
let richestCustomer=function(accounts){
    let maxi=0
    for(let i of accounts){
        let total=i.reduce((a,b)=>a+b,0)
        maxi=Math.max(maxi,total)
    }
    return maxi
}
let accounts = [[1,2,3],[3,2,1]]
console.log(richestCustomer(accounts))
// Out:
// 6

// %%
let countPrime=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime.filter(prime=>prime).length
}
let n=10
console.log(countPrime(n))
// Out:
// 4

// %%
let findLuckYInteger=function(arr){
    let set=new Set(arr),maxi=-1
    for(let i of set){
        let lucky=arr.filter(sh=>sh===i).length
        if(lucky === i){
            maxi=Math.max(maxi,i)
        }
    }
    return maxi
}
let arr=[2,2,3,4]
console.log(findLuckYInteger(arr))
// Out:
// 2

// %%
let luckyInteger=function(arr){
    let set=new Set(arr),maxi=-Infinity
    for(let i of set){
        let index=arr.filter(sh=> sh === i).length
        if(index === i){
            maxi=Math.max(maxi,i)
        }
    }
    return maxi
}
let arr=[2,2,3,4]
console.log(luckyInteger(arr))
// Out:
// 2

// %%
let twoSum=function(nums,target){
    for(let i=0;i<nums.length;i++){
        for(let j=1;j<nums.length;j++){
            if(nums[i]+nums[j]===target){
                return [i,j]
            }
        }
    }
    return [-1,-1]
}
let nums = [2,7,11,15], target = 9
console.log(twoSum(nums,target))
// Out:
// [ 0, 1 ]

// %%
let binarySearch=function(nums,target){
    let left=0,right=nums.length-1
    while(left < right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid]=== target)return mid
        else if(nums[mid] > target) right=mid-1
        else left=mid+1
    }
    return -1
}
let nums = [-1,0,3,5,9,12], target = 9
console.log(binarySearch(nums,target))
// Out:
// 4

// %%
let rotatedArray=function (nums,k){
    k=k%nums.length
    let rotated=nums.slice(-k).concat(nums.slice(0,-k))
    for(let i =0;i<nums.length;i++){
        nums[i]=rotated[i]
    }
    return nums
}
let nums = [1,2,3,4,5,6,7], k = 3
console.log(rotatedArray(nums,k))
// Out:
// [
//   5, 6, 7, 1,
//   2, 3, 4
// ]

// %%
let rotatedArray3=function(nums,k){
    k=k%nums.length
    let rotated=nums.slice(-k).concat(nums.slice(0,-k))
    for(let i=0;i<nums.length;i++){
        nums[i]=rotated[i]
    }
    return nums
}
let nums = [1,2,3,4,5,6,7], k = 3
console.log(rotatedArray3(nums,k))
// Out:
// [
//   5, 6, 7, 1,
//   2, 3, 4
// ]

// %%
let repeatingChar=function(A){
    let freq=new Array(26).fill(0)
    let stack=[],str=''
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            str+=stack[0]
        }
        else{
            str+='#'
        }
    }
    return str
}
let A="abadbc"
console.log(repeatingChar(A))
// Out:
// aabbdd

// %%
let nonRepeatingCHar=function(A){
    let freq=new Array(26).fill(0)
    let ans='',queue=[]
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        queue.push(i)
        while(queue.length && freq[queue[0].charCodeAt(0)-"a".charCodeAt(0)]>1){
            queue.shift()
        }
        if(queue.length){
            ans+=queue[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let A="abadbc"
console.log(nonRepeatingCHar(A))
// Out:
// aabbdd

// %%
let palindrome=function(A){
    A=A.toLowerCase().replace(/[^a-z 0-9]/g,"")
    for(let i=0;i<A.length/2;i++){
        if(A[i] !== A[A.length-1-i])return false
    }
    return true
}
let s="madam"
console.log(palindrome(s))
// Out:
// true

// %%
let binarySearch=function(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid]=== target)return mid
        else if( nums[mid] > target)right=mid-1
        else left=mid+1
    }
    return -1
}
let nums = [-1,0,3,5,9,12], target = 9
console.log(binarySearch(nums,target))
// Out:
// 4

// %%
let onlineStockSpan=function(){
    this.stack=[]
}
onlineStockSpan.prototype.next=function(price){
    let span=1
    while(this.stack && this.stack[this.stack.length-1].price < price){
        span+=this.tack.pop()
    }
    this.stack.push({price,span})
    return span
}

// %%
let insertionSort=function(arr){
    for(let i=0;i<arr.length;i++){
        let temp=arr[i],j=i-1
        while(j>=0 && arr[j] > temp){
            arr[j+1]=arr[j]
            j-- 
        }
        arr[j+1]=temp
    }
    return arr
}
let arr=[4,1,5,2,3]
console.log(insertionSort(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let selectionSort=function(arr){
    for(let i=0;i<arr.length;i++){
        let temp=i 
        for(let j=i;j<arr.length;j++){
            if(arr[j] < arr[temp]){
                temp=j
            }
        }
        let ans=arr[i]
        arr[i]=arr[temp]
        arr[temp]=ans
    }
    return arr
}
let arr=[5,1,2,4,3]
console.log(selectionSort(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let bubbleSort=function(arr){
    for(let i=0;i<arr.length;i++){
        for(let j=0;j<arr.length-1-i;j++){
            if(arr[j] > arr[j+1]){
                let temp=arr[j]
                arr[j]=arr[j+1]
                arr[j+1]=temp
            }
        }
    }
    return arr
}
let arr=[5,1,4,2,3]
console.log(bubbleSort(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let largestRectHisto=function(heights){
    heights.push(0)
    let stack=[-1],maxi=0
    for(let i=0;i<heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
    }
    return maxi
}
let heights = [2,1,5,6,2,3]
console.log(largestRectHisto(heights))
// Out:
// 10

// %%
let maxSlidingWindow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0]<i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]< nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i>=k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(maxSlidingWindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let validParentheses=function(s){
    let dict={'}':'{',')':'(',']':'['},stack=[]
    for(let i of s){
        if(i in dict){
            if(stack.length === 0 || stack.pop() !== dict[i])return false
        }
        else{
            stack.push(i)
        }
    }
    return stack.length === 0
}
let s="[]"
console.log(validParentheses(s))
// Out:
// false

// %%
let trappingRainWater=function(heights){
    let left=0,right=heights.length-1,
    leftMax=heights[left],rightMax=heights[right],
    ans=0
    while(left < right){
        if(leftMax < rightMax){
            left++
            leftMax=Math.max(leftMax,heights[left])
            ans+=leftMax-heights[left]
        }
        else{
            right--
            rightMax=Math.max(rightMax,heights[right])
            ans+=rightMax-heights[right]
        }
    }
    return ans
}  
let  height = [0,1,0,2,1,0,1,3,2,1,2,1]
console.log(trappingRainWater(height))
// Out:
// 6

// %%
let nonRepeatingCHar=function(A){
    let freq=new Array(26).fill(0)
    let stack=[],ans=''
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            ans+=stack[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let A="abadbc"
console.log(nonRepeatingCHar(A))
// Out:
// aabbdd

// %%
let countPrimes=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime.filter(prime=>prime).length
}
let n=10
console.log(countPrimes(n))
// Out:
// 4

// %%
let nonRepeatingCHar=function(A){
    let freq=new Array(26).fill(0),
    ans='',queue=[]
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        queue.push(i)
        while(queue.length && freq[queue[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            queue.shift()
        }
        if(queue.length){
            ans+=queue[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let A="abadbc"
console.log(nonRepeatingCHar(A))
// Out:
// aabbdd

// %%
let maxSlidingWindow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]] < nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i>=k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(maxSlidingWindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let maxSlidingWindow=function(nums,k){
     let queue=[],ans=[]
     for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]<nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i >= k-1){
            ans.push(nums[queue[0]])
        }
     }
     return ans
}
let nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(maxSlidingWindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let nonRepeatingCHar=function(A){
    let freq=new Array(26).fill(0),ans='',queue=[]
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        queue.push(i)
        while(queue.length && freq[queue[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            queue.shift()
        }
        if(queue.length){
            ans+=queue[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let A="abadbc"
console.log(nonRepeatingCHar(A))
// Out:
// aabbdd

// %%
let maxSlidingWindow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift(0)
        }
        while(queue.length && nums[queue[queue.length-1]]<nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i >= k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(maxSlidingWindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]
