// %%
let validParentheses=function(s){
    let dict={'}':'{',']':'[',')':'('},stack=[]
    for(let i of s){
        if(i in dict){
            if(stack.length === 0 || stack.pop() !== dict[i]){
                return false
            }
        }
        else{
            stack.push(i)
        }
    }
    return stack.length === 0
}
let s="({})"
console.log(validParentheses(s))
// Out:
// false

// %%
let maximumSlidingWindow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]<nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i >= k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let  nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(maximumSlidingWindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let largestRectangleHisto=function(heights){
    let maxi=0,queue=[-1]
    for(let i=0;i<heights.length;i++){
        while(heights[i] < heights[queue[queue.length-1]]){
            let left=heights[queue.pop()]
            let right=i-queue[queue.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        queue.push(i)
    }
    return maxi
}
let heights = [2,1,5,6,2,3]
console.log(largestRectangleHisto(heights))
// Out:
// 10

// %%
let largestRectangleHisto=function(heights){
     let maxi=0,stack=[-1]
     for(let i=0;i<heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
     }
     return maxi
}
let  heights = [2,1,5,6,2,3]
console.log(largestRectangleHisto(heights))
// Out:
// 10

// %%
let onlineStockSpan=function(){
    this.stack=[]
}
onlineStockSpan.prototype.next=function(price){
    let span=1
    while(this.stack.length && this.stack[this.stack.length-1].price < price){
        span+=this.stack.pop().span
    }
    this.stack.push({price,span})
    return span
}

// %%
let onlineStockSpan=function(){
    this.stack=[]
}
onlineStockSpan.prototype.next=function(price){
    let span=1
    while(this.stack.length && this.stack[this.stack.length-1].price <= price){
        span+=this.stack.pop().span
    }
    this.stack.push({price,span})
    return span
}

// %%
let trappingRainWater=function(height){
    let left=0,right=height.length-1,
    leftMax=height[left],rightMax=height[right],
    ans=0
    while(left < right){
        if(leftMax < rightMax){
            left++
            leftMax=Math.max(leftMax,height[left])
            ans+=leftMax-height[left]
        }
        else{
            right--
            rightMax=Math.max(rightMax,height[right])
            ans+=rightMax-height[right]
        }
    }
    return ans
}
let  height = [0,1,0,2,1,0,1,3,2,1,2,1]
console.log(trappingRainWater(height))
// Out:
// 6

// %%
let s=""
console.assert(s)
// Out:
// Assertion failed

// %%
let nextGreaterELement=function(nums){
    let arr=[]
    for(let i=0;i<nums.length;i++){
        arr[i]=-1
        for(let j=1;j<nums.length;j++){
            let index=(i+j)%nums.length
            if(nums[index]>nums[i]){
                arr[i]=nums[index]
                break
            }
        }
    }
    return arr
}
let nums=[1,2,1]
console.log(nextGreaterELement(nums))
// Out:
// [ 2, -1, 2 ]

// %%
let decodeString=function(s){
    let stack=[],str='',num=0
    for(let i of s){
        if(!isNaN(i)){
            num=num*10+parseInt(i)
        }
        else if(i === '['){
            stack.push(str)
            stack.push(num)
            str=''
            num=0
        }
        else if(i === ']'){
            let prevNum=stack.pop()
            let prevStr=stack.pop()
            str=prevStr+str.repeat(prevNum)
        }
        else{
            str+=i 
        }
    }
    return str
}
let s="3[a]2[bc]"
console.log(decodeString(s))
// Out:
// aaabcbc

// %%
let removeAdjacent=function(s){
    let stack=[]
    for(let i of s){
        if(stack.length && stack[stack.length-1] === i){
            stack.pop()
        }
        else{
            stack.push(i)
        }
    }
    return stack.join('')
}
let s="abbaca"
console.log(removeAdjacent(s))
// Out:
// ca

// %%
let validateStackSeq=function(pushed,popped){
    let stack=[]
    for(let i of pushed){
        stack.push(i)
        while(stack.length && stack[stack.length-1]===popped[0]){
            stack.pop()
            popped.shift()
        }
    }
    return stack.length===0
}
let  pushed = [1,2,3,4,5], popped = [4,5,3,2,1]
console.log(validateStackSeq(pushed,popped))
// Out:
// true

// %%
let validateStackSeq=function(pushed,popped){
    let stack=[]
    for(let i of pushed){
        stack.push(i)
        while(stack.length && stack[stack.length-1]===popped[0]){
            stack.pop()
            popped.shift()
        }
    }
    return stack.length === 0
}
let  pushed = [1,2,3,4,5], popped = [4,5,3,2,1]
console.log(validateStackSeq(pushed,popped))
// Out:
// true

// %%
let richestCustomerWealth=function(accounts){
    let maxi=0
    for(let i of accounts){
        let total=i.reduce((a,b)=>a+b,0)
        maxi=Math.max(maxi,total)
    }
    return maxi
}
let accounts = [[1,2,3],[3,2,1]]
console.log(richestCustomerWealth(accounts))
// Out:
// 6

// %%
let findLuckyInteger=function(arr){
    let set=new Set(arr),maxi=-1
    for(let i of set){
        let index=arr.filter(sh=>sh===i).length
        if(index === i){
            maxi=Math.max(maxi,i)
        }
    }
    return maxi
}
let arr=[2,2,3,4]
console.log(findLuckyInteger(arr))
// Out:
// 2

// %%
let binarySearch=function(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid] === target)return mid
        else if( nums[mid] > target)right=mid-1 
        else left=mid+1
    }
    return -1
}
let nums = [-1,0,3,5,9,12], target = 9
console.log(binarySearch(nums,target))
// Out:
// 4

// %%
let rotateArray=function(nums,k){
    k=k%nums.length
    let rotated=nums.slice(-k).concat(nums.slice(0,-k))
    for(let i=0;i<nums.length;i++){
        nums[i]=rotated[i]
    }
    return nums

}
let nums = [1,2,3,4,5,6,7], k = 3
console.log(rotateArray(nums,k))
// Out:
// [
//   5, 6, 7, 1,
//   2, 3, 4
// ]

// %%
let maximumWordInSentence=function(sentences){
    let maxi=0
    for(let i of sentences){
        let word=i.split(' ')
        maxi=Math.max(maxi,word.length)
    }
    return maxi
}
let sentences = ["alice and bob love leetcode", "i think so too", "this is great thanks very much"]
console.log(maximumWordInSentence(sentences))
// Out:
// 6

// %%
let transposeMatrix=function(matrix){
    let arr=[]
    for(let i=0;i<matrix.length;i++){
        arr[i]=[]
        for(let j=0;j<matrix[0].length;j++){
            arr[i].push(matrix[j][i])
        }
    }
    return arr
}
let matrix = [[1,2,3],[4,5,6],[7,8,9]]
console.log(transposeMatrix(matrix))
// Out:
// [ [ 1, 4, 7 ], [ 2, 5, 8 ], [ 3, 6, 9 ] ]

// %%
let maxiConsecutiveOnes=function(nums){
    let maxi=0,count=0
    for(let i=0;i<nums.length;i++){
        if(nums[i] === 1){
            count++
            maxi=Math.max(maxi,count)
        }
        else{
            count=0
        }
    }
    return maxi
}
let nums=[1,1,0,1,1,1]
console.log(maxiConsecutiveOnes(nums))
// Out:
// 3

// %%
let sortNumberBits=function(arr){
    return arr.sort((a,b)=>{
        let A=a.toString(2).split('').filter(i=>i==='1').length
        let B=b.toString(2).split('').filter(i=>i==='1').length
        return A-B || a-b 
    })
}
let arr=[0,1,2,3,4,5,6,7,8]
console.log(sortNumberBits(arr))
// Out:
// [
//   0, 1, 2, 4, 8,
//   3, 5, 6, 7
// ]

// %%
let numberOfOnesBits=function(n){
    n=n.toString(2)
    let count=0
    for(let i=0;i<n.length;i++){
        if(n[i] === '1')
            count++
    }
    return count
}
let n=11
console.log(numberOfOnesBits(n))
// Out:
// 3

// %%
let hamminghWeight=function(n){
    let count=0
    while(n){
        n&=n-1
        count++
    }
    return count
}
let n=11
console.log(hamminghWeight(n))
// Out:
// 3

// %%
let countPrime=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime.filter(i=>i).length
}
let n=10
console.log(countPrime(n))
// Out:
// 4

// %%
let countPrimes=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime(i=>i).length
}
let n=10
console.log(countPrime(n))
// Out:
// 4

// %%
let nonRepeatingChar=function(A){
    let freq=new Array(26).fill(0)
    let str='',stack=[]
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            str+=stack[0]
        }
        else{
            str+=i
        }
    }
    return str

}
let A="abadbc"
console.log(nonRepeatingChar(A))
// Out:
// aabbdd

// %%
let nonRepeatingChar=function(A){
    let freq=new Array(26).fill(0)
    let ans='',queue=[]
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        queue.push(i)
        while(queue.length && freq[queue[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            queue.shift()
        }
        if(queue.length){
            ans+=queue[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let A="abadbc"
console.log(nonRepeatingChar(A))
// Out:
// aabbdd

// %%
let nonRepeatingChar=function(A){
    let freq=new Array(26).fill(0)
    let queue=[],ans=''
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        queue.push(i)
        while(queue.length && freq[queue[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            queue.shift()
        }
        if(queue.length){
            ans+=queue[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let A="abadbc"
console.log(nonRepeatingChar(A))
// Out:
// aabbdd

// %%
let countPrime=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime.filter(prime=>prime).length
}
let n=10
console.log(countPrime(n))
// Out:
// 4

// %%
let twoSum=function(nums,target){
    for(let i=0;i<nums.length;i++){
        for(let j=0;j<nums.length;j++){
            if(nums[i]+nums[j]===target){
                return [i,j]
            }
        }
    }
    return [-1,-1]
}

let nums = [2,7,11,15], target = 9
console.log(twoSum(nums,target))
// Out:
// [ 0, 1 ]

// %%
let checkPlaindrome=function(word){
    word=word.toLowerCase().replace(/[^a-z0-9]/g,'')
    for(let i=0;i<word.length/2;i++){
        if(word[i] !== word[word.length-1-i]){
            return false
        }
    }
    return true
}
let word="madam"
console.log(checkPlaindrome(word))
// Out:
// true

// %%
let nonRepeatingChar=function(A){
    let freq=new Array(26).fill(0)
    let queue=[],ans=''
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        queue.push(i)
        while(queue.length && freq[queue[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            queue.shift()
        }
        if(queue.length){
            ans+=queue[0]
        }
        else{
            ans+='#'
        }
    }
    return ans
}
let A="abadbc"
console.log(nonRepeatingChar(A))
// Out:
// aabbdd

// %%
let slidingWindow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]<nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i >= k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let nums=[1,3,-1,-3,5,3,6,7],k=3
console.log(slidingWindow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let largestRectangleHistogram=function(heights){
    heights.push(0)
    let stack=[-1],maxi=0
    for(let i=0;i<heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
    }
    return maxi
}
let heights=[2,1,5,6,2,3]
console.log(largestRectangleHistogram(heights))
// Out:
// 10

// %%
let histo=function(heights){
    heights.push(0)
    let stack=[-1],maxi=0
    for(let i=0;i<heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
    }
    return maxi
}
let heights=[2,1,5,6,2,3]
console.log(histo(heights))
// Out:
// 10

// %%
let maxiSlidingWIndow=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]<nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i >= k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let  nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(maxiSlidingWIndow(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
let validParentheses=function(s){
    let dict={']':'[','}':'{',')':'('},stack=[]
    for(let i of s){
        if(i in dict){
            if(stack.length === 0 || stack.pop() !== dict[i])return false
        }
        else stack.push(i)
    }
    return stack.length === 0
}
let s="[(]"
console.log(validParentheses(s))
// Out:
// false

// %%
let onlineStockSpan=function(){
    this.stack=[]
}
onlineStockSpan.prototype.next=function(price){
    let span=1 
    while(this.stack.length && this.stack[this.stack.length-1].price <= price){
        span+=this.stack.pop().span
    }
    this.stack.push({price,span})
    return span
}

// %%
let trappingRainWater=function(height){
    let left=0,right=height.length-1,
    leftMax=height[left],rightMax=height[right],
    ans=0
    while(left < right){
        if(leftMax < rightMax){
            left++
            leftMax=Math.max(leftMax,height[left])
            ans+=leftMax-height[left]
        }
        else{
            right--
            rightMax=Math.max(rightMax,height[right])
            ans+=rightMax-height[right]
        }
    }
    return ans
}
let  height = [0,1,0,2,1,0,1,3,2,1,2,1]
console.log(trappingRainWater(height))
// Out:
// 6

// %%
let nextGreaterElement=function(nums){
    let arr=[]
    for(let i=0;i<nums.length;i++){
        arr[i]=-1
        for(let j=0;j<nums.length;j++){
            let index=(i+j)%nums.length
            if(nums[index]>nums[i]){
                arr[i]=nums[index]
                break
            }
        }
    }
    return arr
}
let nums=[1,2,1]
console.log(nextGreaterElement(nums))
// Out:
// [ 2, -1, 2 ]

// %%
let decodeString=function(s){
    let str='',num=0,stack=[]
    for(let i of s){
        if(!isNaN(i)){
            num=num*10+parseInt(i)
        }
        else if(i === '['){
            stack.push(str)
            stack.push(num)
            str=''
            num=0
        }
        else if(i === ']'){
            let prevNum=stack.pop()
            let prevStr=stack.pop()
            str=prevStr+str.repeat(prevNum)
        }
        else{
            str+=i 
        }
    }
    return str
}
let s="3[a]2[bc]"
console.log(decodeString(s))
// Out:
// aaabcbc

// %%
let removeAllAdjacentDup=function(s){
    let stack=[]
    for(let i of s){
        if(stack.length && stack[stack.length-1]===i)stack.pop()
        else stack.push(i)
    }
    return stack.join('')
}
let s="abbaca"
console.log(removeAllAdjacentDup(s))
// Out:
// ca

// %%
let validateStackSeq=function(pushed,popped){
    let stack=[]
    for(let i of pushed){
        stack.push(i)
        while(stack.length && stack[stack.length-1]=== popped[0]){
            popped.shift()
            stack.pop()
        }
    }
    return stack.length === 0
}
let pushed = [1,2,3,4,5], popped = [4,5,3,2,1]
console.log(validateStackSeq(pushed,popped))
// Out:
// true

// %%
let richestCustomer=function(accounts){
    let maxi=0
    for(let i of accounts){
        let total=i.reduce((a,b)=>a+b,0)
        maxi=Math.max(maxi,total)
    }
    return maxi
}
let accounts = [[1,2,3],[3,2,1]]
console.log(richestCustomer(accounts))
// Out:
// 6

// %%
let findLuckyInt=function(arr){
    let set=new Set(arr)
    let maxi=0
    for(let i of set){
        let lucky=arr.filter(sh=>sh===i).length
        if(i === lucky){
            maxi=Math.max(maxi,i)
        }
    }
    return maxi
}
let arr=[2,2,3,4]
console.log(findLuckyInt(arr))
// Out:
// 2

// %%
let binarySearch=function(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid] === target)return mid
        else if(nums[mid] > target)right=mid-1 
        else left=mid+1
    }
    return -1
}
let nums=[-1,0,3,5,9,12], target = 9
console.log(binarySearch(nums,target))
// Out:
// 4

// %%
let rotatedArray=function(nums,k){
    k=k%nums.length
    let rotated=nums.slice(-k).concat(nums.slice(0,-k))
    for(let i=0;i<nums.length;i++){
        nums[i]=rotated[i]
    }
    return nums
}
let nums = [1,2,3,4,5,6,7], k = 3
console.log(rotatedArray(nums,k))
// Out:
// [
//   5, 6, 7, 1,
//   2, 3, 4
// ]

// %%
let maxiWordInSentence=function(sentence){
    let maxi=0
    for(let i of sentence){
        let word=i.split(' ')
        maxi=Math.max(maxi,word.length)
    }
    return maxi
}
let sentences = ["alice and bob love leetcode", "i think so too", "this is great thanks very much"]
console.log(maxiWordInSentence(sentences))
// Out:
// 6

// %%
let transposeMatrix=function(matrix){
    let arr=[]
    for(let i=0;i<matrix.length;i++){
        arr[i]=[]
        for(let j=0;j<matrix[0].length;j++){
            arr[i].push(matrix[j][i])
        }
    }
    return arr
}
let  matrix = [[1,2,3],[4,5,6],[7,8,9]]
console.log(transposeMatrix(matrix))
// Out:
// [ [ 1, 4, 7 ], [ 2, 5, 8 ], [ 3, 6, 9 ] ]

// %%
let transposeMatrix=function(matrix){
    let arr=[]
    for(let i=0;i<matrix.length;i++){
        arr[i]=[]
        for(let j=0;j<matrix[0].length;j++){
            arr[i].push(matrix[j][i])
        }
    }
    return arr
}
let matrix = [[1,2,3],[4,5,6],[7,8,9]]
console.log(transposeMatrix(matrix))
// Out:
// [ [ 1, 4, 7 ], [ 2, 5, 8 ], [ 3, 6, 9 ] ]

// %%
let maximumConsecutiveOnes=function(nums){
    let count=0,maxi=-1
    for(let i =0;i<nums.length;i++){
        if(nums[i] === 1){
            count++
            maxi=Math.max(maxi,count)
        }
        else{
            count=0
        }
    }
    return maxi
}
let nums=[1,1,0,1,1,1]
console.log(maximumConsecutiveOnes(nums))
// Out:
// 3

// %%
let sortBitsByOnesBit=function(arr){
    return arr.sort((a,b)=>{
        let A=a.toString(2).split('').filter(i=>i==='1').length
        let B=b.toString(2).split('').filter(i=>i==='1').length
        return A-B || a-b     
    })
}
let arr=[0,1,2,3,4,5,6,7,8]
console.log(sortBitsByOnesBit(arr))
// Out:
// [
//   0, 1, 2, 4, 8,
//   3, 5, 6, 7
// ]

// %%
function numberOf1Bit(n){
    n=n.toString(2)
    let count=0
    for(let i=0;i<n.length;i++){
        if(n[i] === '1'){
            count++
        }

    }
    return count
}
let n=11
console.log(numberOf1Bit(n))
// Out:
// 3

// %%
function numberof1Bits(n){
    let count=0
    while(n){
        n&=n-1 
        count++
    }
    return count
}
let n=11
console.log(numberof1Bits(n))
// Out:
// 3

// %%
let countPrime=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime.filter(prime=>prime).length
}
let n=10
console.log(countPrime(n))
// Out:
// 4

// %%
let twoSum=function(nums,target){
    for(let i=0;i<nums.length;i++){
        for(let j=0;j<nums.length;j++){
            if(nums[i]+nums[j] === target){
                return [i,j]
            }
        }
    }
    return [-1,-1]
}
let nums=[2,7,11,15],target=9
console.log(twoSum(nums,target))
// Out:
// [ 0, 1 ]

// %%
let n=11
n=n.toString(2)
console.log(n)
// Out:
// 1011

// %%
let n='100101'
n=parseInt(n,2)
console.log(n)
// Out:
// 37

// %%
let hamminghWeight=function(n){
    let count=0
    while(n){
        n&=n-1 
        count++
    }
    return count
}
let n='0b00000000000000000000000000001011'
console.log(hamminghWeight(n))
// Out:
// 3

// %%
let hammingh=function(n){
    n=n.toString(2)
    let count=0
    for(let i=0;i<n.length;i++){
        if(n[i] === '1'){
            count++
        }
    }
    return count
}
let n=0b00000000000000000000000000001011
console.log(hammingh(n))
// Out:
// 3

// %%
let alternateBits=function(n){
    n=n.toString(2)
    for(let i=1;i<n.length;i++){
        if(n[i] === n[i-1])return false
    }
    return true
}
let n=7
console.log(alternateBits(n))
// Out:
// false

// %%
let hexaDecimal=function(num){
    if(num === 0)return '0'
    let hex='0123456789abcdef',ans=''
    while(num>0){
        ans=hex[num%16]+ans
        num=Math.floor(num/16)
    }
    return ans
}
let num=26
console.log(hexaDecimal(num))
// Out:
// 1a

// %%
let hexaDecimal=function(nums){
    if(nums === 0)return '0'
    if(nums < 0) nums+=0xffffffff+1
    return nums.toString(16)
}
let nums=26
console.log(hexaDecimal(nums))
// Out:
// 1a

// %%
// def toHexa(nums):
//     if(nums == 0):
//         return '0'
//     hex='0123456789abcdef'
//     ans=''
//     while(nums):
//         ans=hex[nums%16]+ans
//         nums=nums//16
//     return ans
// nums=26
// print(toHexa(nums))
// Out:
// 1a

// %%
function toHexa(num){
    if(num === 0)return '0'
    if(num < 0) num+=0xffffffff+1
    return num.toString(16)
}
let num=26
console.log(toHexa(num))
// Out:
// 1a

// %%
let sortIntByOnesBit=function(arr){
    return arr.sort((a,b)=>{
        let A=a.toString(2).split('').filter(i=>i==='1').length
        let B=b.toString(2).split('').filter(i=>i==='1').length
        return A-B || a-b 
    })
}
let arr = [0,1,2,3,4,5,6,7,8]
console.log(sortIntByOnesBit(arr))
// Out:
// [
//   0, 1, 2, 4, 8,
//   3, 5, 6, 7
// ]

// %%
let divideTwoInteger=function(dividend,divisor){
    let res=parseInt(dividend/divisor)
    if(res > 2147483647){
        return 2147483647
    }
    else if(res < -2147483648){
        return -2147483648
    }
    else return res
}
let d=10,di=3
console.log(divideTwoInteger(d,di))
// Out:
// 3

// %%
let maximumNumberOfWOrds=function(sentence){
    let maxi=0
    for(let i of sentence){
        let word=i.split(' ')
        maxi=Math.max(maxi,word.length)
    }
    return maxi
}
let sent=["alice and bob love leetcode", "i think so too", "this is great thanks very much"]
console.log(maximumNumberOfWOrds(sent))
// Out:
// 6

// %%
function toHex(num){
    if(num === 0)return '0'
    else if(num < 0) num+=0xffffffff+1
    return num.toString(16)
}
let num=26
console.log(toHex(num))
// Out:
// 1a

// %%
class Student{
    constructor(name,roll_no){
        this.name=name
        this.roll_no=roll_no
    }
    display(){
        console.log(`Name: ${this.name}, Roll-Number: ${this.roll_no}`)
    }
}
let s=new Student('Arjun',45)
s.display()
// Out:
// Name: Arjun, Roll-Number: 45

// %%
class Triangle{
    constructor(side1,side2,side3){
        this.side1=side1
        this.side2=side2 
        this.side3=side3
    }
    calculate_area(){
        return this.side1*this.side2*this.side3
    }
    calculate_perimeter(){
        return this.side1+this.side2+this.side3 
    }
}
let t=new Triangle(12,6,22)
console.log(t.calculate_area())
console.log(t.calculate_perimeter())
// Out:
// 1584
// 40

// %%
class Employee{
    constructor(name,year_of_joining,address){
        this.name=name
        this.year_of_joining=year_of_joining
        this.address=address
    }
    print_Details(){
        console.log(`${this.name}  ${this.year_of_joining} ${this.address}`)
    }
}
let e=[
    new Employee("Robert",1994,"64C-WallsStreet"),
    new Employee("Sam",2000,"68D-WallsStreet"),
    new Employee("John" ,1999, "26B WallsStreet")
]
for(let i of e){
    i.print_Details()
}
// Out:
// Robert  1994 64C-WallsStreet
// Sam  2000 68D-WallsStreet
// John  1999 26B WallsStreet

// %%
class Employee{
    getInfo(salary,working_hours){
        this.salary=salary
        this.working_hours=working_hours
    }
    AddSal(){
        if(this.salary < 500){
            this.salary+=10
        }
    }
    AddWork(){
        if(this.working_hours>6){
            this.salary+=5
        }
    }
}
let e=new Employee()
e.getInfo(450,7)
e.AddSal()
e.AddWork()
console.log(e.salary)
// Out:
// 465

// %%
class count_objects{
    static count=0
    constructor(name,age){
        this.name=name
        this.age=age
        count_objects.count++

    }
    print_details(){
        console.log(`${this.name} ${this.age}`)
        //console.log(count_objects.count++)
    }
}
let s1=new count_objects('Gaurav',23)
let s2=new count_objects('Saurav',45)
s1.print_details()
s2.print_details()
console.log(count_objects.count)
// Out:
// Gaurav 23
// Saurav 45
// 2

// %%
class Shape{
    printShape(){
        console.log('This is shape')
    }
}
class Rectangle extends Shape{
    print(){
        console.log("This is rectangle")
    }
}
class Circle extends Shape{
    print(){
        console.log("This is circle")
    }
}
class Square extends Rectangle{
    printSquare(){
        console.log("Square is a rectangle")
    }
}
let s=new Shape()
s.printShape()

let r=new Rectangle()
r.printShape()
r.print()

let c=new Circle()
c.print()

let sq=new Square()
sq.printShape()
sq.print()
sq.printSquare()
// Out:
// This is shape
// This is shape
// This is rectangle
// This is circle
// This is shape
// This is rectangle
// Square is a rectangle

// %%
class PARENT{
    print(){
        console.log("this is a parent class")
    }
}
class CHILD extends PARENT{
    print(){
        console.log("this is a child class")
        super.print()
    }
}
let p=new PARENT()
p.print()

let c=new CHILD()
c.print()
// Out:
// this is a parent class
// this is a child class
// this is a parent class

// %%
class Member{
    constructor(name,age,phone_number,address,salary){
        this.name=name
        this.age=age
        this.phone_number=phone_number
        this.address=address
        this.salary=salary
    }
    printSalary(){
        console.log(`Salary: ${this.salary}`)
    }
}
class Employee extends Member{
    constructor(name,age,phone_number,address,salary,specialization){
        super(name,age,phone_number,address,salary)
        this.specialization=specialization
    }
    print_details(){
        console.log(`Name: ${this.name}  Specialization: ${this.specialization}`)
    }
}
class Manager extends Member{
    constructor(name,age,phone_number,address,salary,department){
        super(name,age,phone_number,address,salary)
        this.department=department
    }
    print_details(){
        console.log(`Name: ${this.name} department: ${this.department}`)
    }
}

let e=new Employee('gaurav',23,345677,"Patna",75000,'Developer')
e.printSalary()
e.print_details()

let m=new Manager('Dhiraj',29,6896060,'Vaishali',98000,'SDE')
m.printSalary()
m.print_details()
// Out:
// Salary: 75000
// Name: gaurav  Specialization: Developer
// Salary: 98000
// Name: Dhiraj department: SDE

// %%
let binarySearch=function(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid] === target){
            return mid
        }
        else if(nums[mid] > target){
            right=mid-1
        }
        else{
            left=mid+1
        }
    }
    return -1
}
let  nums = [-1,0,3,5,9,12], target = 9
console.log(binarySearch(nums,target))
// Out:
// 4

// %%
let peakElement=function(nums){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid] > nums[mid+1]){
            right=mid-1
        }
        else{
            left=mid+1
        }
    }
    return left
}
let nums=[1,2,3,1]
console.log(peakElement(nums))
// Out:
// 2

// %%
function search(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid] === target)return mid
        else if(nums[mid] > nums[left]){
            if(target <= nums[mid] && target >= nums[left]){
                right=mid-1
            }
            else{
                left=mid+1
            }
        }
        else{
            if(target >= nums[mid] && target <= nums[right]){
                left=mid+1 
            }
            else{
                right=mid-1 
            }
        }
    }
    return -1
}
let nums = [4,5,6,7,0,1,2], target = 0
console.log(search(nums,target))
// Out:
// 4

// %%
let rotatedSearchArray=function(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid] === target)return mid
        else if(nums[mid] > nums[left]){
            if(target <= nums[mid+1] && target >= nums[left]){
                right=mid-1 
            }
            else{
                left=mid+1
            }
        }
        else{
            if(target >= nums[mid] && target <= nums[right]){
                left=mid+1
            }
            else{
                right=mid-1 
            }
        }
    }
    return -1
}
let nums = [4,5,6,7,0,1,2], target = 0
console.log(rotatedSearchArray(nums,target))
// Out:
// 4

// %%
let searchRotatedArray=function(nums,target){
    let left=0,right=nums.length-1
    while(left <= right){
        let mid=Math.floor((left+right)/2)
        if(nums[mid] ===target)return mid
        else if(nums[mid] >= nums[left]){
            if(target <= nums[mid] && target >=nums[left]){
                right=mid-1 
            }
            else{
                left=mid+1
            }
        }
        else{
            if(target >= nums[mid] && target <= nums[right]){
                left=mid+1
            }
            else{
                right=mid-1 
            }
        }
    }
    return -1
}
let nums = [4,5,6,7,0,1,2], target = 0
console.log(searchRotatedArray(nums,target))
// Out:
// 4

// %%
let twoSum=function(nums,target){
    for(let i=0;i<nums.length;i++){
        for(let j=i+1;j<nums.length;j++){
            if((nums[i]+nums[j])===target){
                return [i,j]
            }
        }
    }
    return [-1,-1]
}
let  nums = [2,7,11,15], target = 9
console.log(twoSum(nums,target))
// Out:
// [ 0, 1 ]

// %%
let luckyInteger=function(arr){
    let set=new Set(arr),maxi=-1
    for(let i of set){
        let lucky=arr.filter(sh=>sh===i).length
        if(i === lucky){
            maxi=Math.max(maxi,i)
        }
    }
    return maxi
}
let arr=[2,2,3,4]
console.log(luckyInteger(arr))
// Out:
// 2

// %%
class Employee{
    constructor(name,salary){
        this.name=name
        this.salary=salary
    }
}
let emp=[
    new Employee('Babu_Rao',150),
    new Employee("Raju",160),
    new Employee("Shyam",140),
    new Employee("Pappu",200)
]
function sortEmployee(emp){
    for(let i=0;i<emp.length;i++){
        let temp=emp[i]
        let j=i-1 
        while(j>=0 && emp[j].salary > temp.salary){
            emp[j+1]=emp[j]
            j--
        }
        emp[j+1]=temp
    }
    return emp
}
console.log(sortEmployee(emp))
// Out:
// [
//   Employee { name: "Shyam", salary: 140 },
//   Employee { name: "Babu_Rao", salary: 150 },
//   Employee { name: "Raju", salary: 160 },
//   Employee { name: "Pappu", salary: 200 }
// ]

// %%
let countPrime=function(n){
    let isPrime=new Array(n).fill(true)
    isPrime[0]=isPrime[1]=false
    for(let i=2;i*i<n;i++){
        if(isPrime[i]){
            for(let j=i*i;j<n;j+=i){
                isPrime[j]=false
            }
        }
    }
    return isPrime.filter(prime=>prime).length
}
let n=10
console.log(countPrime(n))
// Out:
// 4

// %%
let jewelsAndStone=function(jewels,stones){
    let count=0
    for(let i=0;i<jewels.length;i++){
        for(let j=0;j<stones.length;j++){
            if(jewels[i] === stones[j]){
                count++
            }
        }
    }
    return count
}
let jewels = "aA", stones = "aAAbbbb"
console.log(jewelsAndStone(jewels,stones))
// Out:
// 3

// %%
let validParentheses=function(s){
    let dict={']':'[','}':'{',')':'('},stack=[]
    for(let i of s){
        if(i in dict){
            if(stack.length === 0 || stack.pop() !== dict[i])return false
        }
        else stack.push(i)
    }
    return stack.length === 0
}
let s="{{}}"
console.log(validParentheses(s))
// Out:
// true

// %%
let validateStackSeq=function(pushed,popped){
    let stack=[]
    for(let i  of pushed){
        stack.push(i)
        while(stack.length && stack[stack.length-1] === popped[0]){
            stack.pop()
            popped.shift()
        }
    }
    return stack.length === 0
}
let pushed = [1,2,3,4,5], popped = [4,5,3,2,1]
console.log(validateStackSeq(pushed,popped))
// Out:
// true

// %%
let removeAdjacent=function(s){
    let stack=[]
    for(let i of s){
        if(stack.length && stack[stack.length-1]===i){
            stack.pop()
        }
        else{
            stack.push(i)
        }
    }
    return stack.join('')
}
let s="abbaca"
console.log(removeAdjacent(s))
// Out:
// ca

// %%
let decodeString=function(s){
    let stack=[],num=0,str=''
    for(let i of s){
        if(!isNaN(i)){
            num=num*10+parseInt(i)
        }
        else if(i === '['){
            stack.push(str)
            stack.push(num)
            str=''
            num=0
        }
        else if(i === ']'){
            let prevNum=stack.pop()
            let prevStr=stack.pop()
            str=prevStr+str.repeat(prevNum)
        }
        else{
            str+=i 
        }
    }
    return str
}
let s="3[a]2[bc]"
console.log(decodeString(s))
// Out:
// aaabcbc

// %%
let nextGreaterElement=function(nums){
    let arr=[]
    for(let i=0;i<nums.length;i++){
        arr[i]=-1
        for(let j=1;j<nums.length;j++){
            let index=(i+j)%nums.length
            if(nums[index]> nums[i]){
                arr[i]=nums[index]
                break
            }
        }
    }
    return arr
}
let nums=[1,2,1]
console.log(nextGreaterElement(nums))
// Out:
// [ 2, -1, 2 ]

// %%
let stockSpan=function(){
    this.stack=[]
}
stockSpan.prototype.next=function(price){
    let span=1
    while(this.stack.length && this.stack[this.stack.length-1].price <= price){
        span+=this.stack.pop().span
    }
    this.stack.push({price,span})
    return span
}

// %%
let largestRectangleHisto=function(heights){
    let stack=[-1],maxi=0
    for(let i=0;i<heights.length;i++){
        while(heights[i] < heights[stack[stack.length-1]]){
            let left=heights[stack.pop()]
            let right=i-stack[stack.length-1]-1
            maxi=Math.max(maxi,(left*right))
        }
        stack.push(i)
    }
    return maxi
}
let heights=[2,1,5,6,2,3]
console.log(largestRectangleHisto(heights))
// Out:
// 10

// %%
class Queue{
    constructor(){
        this.queue=[]
    }
    Enqueue(val){
        this.queue.push(val)
    }
    Dequeue(){
        if(!this.is_empty()){
            return this.queue.shift()
        }
    }
    is_empty(){
        return this.queue.length === 0
    }
    get_first_element(){
        if(!this.is_empty()){
            return this.queue[0]
        }
    }
}
let q=new Queue()
q.Enqueue(12)
q.Enqueue(24)
q.Enqueue(36)
q.Dequeue()
q.is_empty()
q.get_first_element()
// Out:
// 24

// %%
let nonRepeatingChar=function(A){
    let freq=new Array(26).fill(0)
    let str='',stack=[]
    for(let i of A){
        let index=i.charCodeAt(0)-'a'.charCodeAt(0)
        freq[index]++
        stack.push(i)
        while(stack.length && freq[stack[0].charCodeAt(0)-'a'.charCodeAt(0)]>1){
            stack.shift()
        }
        if(stack.length){
            str+=stack[0]
        }
        else{
            str+='#'
        }
    }
    return str
}
let A="aabc"
console.log(nonRepeatingChar(A))
// Out:
// a#bb

// %%
let slidingWIndowMaximum=function(nums,k){
    let queue=[],ans=[]
    for(let i=0;i<nums.length;i++){
        while(queue.length && queue[0] < i-k+1){
            queue.shift()
        }
        while(queue.length && nums[queue[queue.length-1]]<= nums[i]){
            queue.pop()
        }
        queue.push(i)
        if(i>=k-1){
            ans.push(nums[queue[0]])
        }
    }
    return ans
}
let nums = [1,3,-1,-3,5,3,6,7], k = 3
console.log(slidingWIndowMaximum(nums,k))
// Out:
// [ 3, 3, 5, 5, 6, 7 ]

// %%
//creating node chain for linked list
class Node{
    constructor(value){
        this.value=value
        this.next=null
    }
}
let n1=new Node(10)
let n2=new Node(30)
n1.next=n2
console.log(n1.value ,"--->",n1.next.value)
// Out:
// 10 ---> 30

// %%
class Node{
    constructor(data){
        this.data=data
        this.next=null
    }
}
class linkedList{
    constructor(){
        this.head=null
    }
    append(data){
        let newNode=new Node(data)
        if(!this.head){
            this.head=newNode
            return
        }
        let current=this.head
        while(current.next){
            current=current.next
        }
        current.next=newNode
    }
    print(){
        let current=this.head
        let result=''
        while(current){
            result+=current.data
            current=current.next
        }
        console.log(result)
    }
    insertNodeMiddle(index,data){
        let newNode=new Node(data)
        if(index === 0 || !this.head){
            newNode.next=this.head
            this.head=newNode
            return
        }
        let current=this.head
        for(let i=0;i<index&&current;i++){
            current=current.next
        }
        if(current){
            newNode.next=current.next
            current.next=newNode
        }
    }
    insertAtBeginning(data){
        let newNode=new Node(data)
        newNode.next=this.head
        this.head=newNode
    }
    
}

// %%
class Node{
    constructor(data){
        this.data=data
        this.next=null
    }
}
class LinkedList{
    constructor(){
        this.head=null
    }
    removeNode(head,val){
        let newNode=new Node(data)
        newNode.next=this.head
        let current=newNode
        while(current.next){
            if(current.next.val === val){
                current.next=current.next.next
            }
            current=current.next
        }
        return newNode.next
    }
}

// %%
class Node{
    constructor(data){
        this.data=data
        this.next=null
    }
}
class linkedList{
    constructor(){
        this.head=null
    }
    append(data){
        let newNode=new Node(data)
        if(!this.head){
            this.head=newNode
            //break
        }
        let current=this.head
        while(current.next){
            current=current.next
        }
        current.next=newNode
    }
    removeELement(data){
        let newNode=new Node(0)
        newNode.next=this.head
        let current=newNode
        while(current.next){
            if(current.next.val === 0){
                current.next=current.next.next
            }
            else{
                current=current.next
            }
        }
        this.head = newNode.next

    }
    deleteNode(){
        if(this.head.next){
            this.head.val=this.head.next.val
            this.head.next=this.head.next.next
        }

    }
}
// Out:
// Stack trace:
// ReferenceError: ListNode is not defined
//     at removeElements (<anonymous>:6:17)
//     at <anonymous>:27:13

// %%
let palindromeLinkedList=function(head){
    let slow=head,fast=head,prev=null
    while(fast && fast.next){
        fast=fast.next.next
        let next=slow.next
        slow.next=prev
        prev=slow
        slow=next
    }
    if(fast){
        fast=fast.next
    }
    while(prev && slow){
        if(prev.val !== slow.val)return false
        prev=prev.next
        slow=slow.next
    }
    return true
}

// %%
function sum(n){
    if(n === 0)return 0
    return n+sum(n-1)
}
console.log(sum(4))
// Out:
// 10

// %%
function sum(a,b){
    if(a===b)return a
    if(a < b) return a+sum(a+1,b)
    return a+sum(a-1,b)
}
let a=5,b=5
console.log(sum(a,b))
// Out:
// 5

// %%
function countDOwn(n){
    if(n===0)return
    
    countDOwn(n-1)
    console.log(n)
}
countDOwn(5)
// Out:
// 1
// 2
// 3
// 4
// 5

// %%
function multiply(a){
    if(a===1)return 1
    return a*multiply(a-1)
}
console.log(multiply(4))
// Out:
// 24

// %%
function add(n){
    if(n === 0)return 0
    return n+add(n-1)
}
console.log(add(4))
// Out:
// 10

// %%
function substract(n){
    if(n===0)return 0
    return n-substract(n-1)
}
console.log(substract(4))
// Out:
// 2

// %%
function oddEven(n){
    if(n===0)return 'even'
    if(n===1)return 'odd'
    return oddEven(n-2)
}
let n=10
console.log(oddEven(n))
// Out:
// even

// %%
function isPalindrome(str){
    if(str.length <= 1)return true
    if(str[0] !== str[str.length-1])return false
    return isPalindrome(str.slice(1,-1))
}
let str='racecar'
console.log(isPalindrome(str))
// Out:
// true

// %%
function recursiveSum(n){
    let i=0
    function total(i){
        if(i === n || i>=n){
            return 0
        }
        return i+total(i+2)
    }
    return total(i)
}
let n=5
console.log(recursiveSum(n))
// Out:
// 6

// %%
function sum(n){
    let i=0
    function total(i){
        if(i === n || i>=n){
            return 0
        }
        return i+total(i+2)
    }
    return total(i)
}
let n=10
console.log(sum(n))
// Out:
// 20

// %%
function sum(n){
    let i=0
    function total(i){
        if(i === n || i>=n){
            return 0
        }
        return i+total(i+2)
    }
    return total(i)
}
console.log(sum(5))
// Out:
// 6

// %%
function sum(n){
    let i=0
    function total(i){
        if(i === n || i>=n){
            return 0
        }
        return i+total(i+2)
    }
    return total(i)
}
console.log(sum(5))
// Out:
// 6

// %%
function sum(n){
    let i=0
    function total(i){
        if(i === n || i>=n)return 0
        return i+total(i+2)
    }
    return total(i)
}
let n=5
console.log(sum(n))
// Out:
// 6

// %%
function count(n){
    let i=0
    function inc(i){
        if(i>5){
            return 0
        }
        return i+inc(i+1)
    }
    return inc(n)
}
let n=1
console.log(count(n))
// Out:
// 15

// %%
function countN(n){
    let i=0
    function inc(i){
        if(i>5){
            return 0
        }
        return i+inc(i+1)
    }
    return inc(i)
}
let n=1
console.log(countN(n))
// Out:
// 15

// %%
function count(i){
    if(i > 5)return 0
    return i*count(i+1)
}
console.log(count(1))
// Out:
// 120

// %%
function count(i){
    if(i === 5)return 0
    return i+count(i+3)
}
console.log(count(1))
// Out:
// Stack trace:
// RangeError: Maximum call stack size exceeded
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)
//     at count (<anonymous>:1:1)

// %%
function count(i){
    if(i === 6){
        return 
    }
    console.log(i)
    return count(i+1)
}
count(1)
// Out:
// 1
// 2
// 3
// 4
// 5
// 1

// %%
function count(i){
    if(i === 6)return
    else count(i+1)
    console.log(i)
}
count(1)
// Out:
// 5
// 4
// 3
// 2
// 1

// %%
function count(i){
    if(i === 6)
        return
    else{
        console.log(i)
        count(i+1)
        console.log(i)
    }
}
count(1)
// Out:
// 1
// 2
// 3
// 4
// 5
// 5
// 4
// 3
// 2
// 1

// %%
function multipleOfFive(n){
    //let i=1
    function iterate(i){
        if(i > n){
            return 
        }
        console.log(i)
        iterate(i+5)
    }
    iterate(5)
    
}
(multipleOfFive(50))
// Out:
// 5
// 10
// 15
// 20
// 25
// 30
// 35
// 40
// 45
// 50

// %%
function multiply(n){
    function into(i){
        if(i > n)return 
        console.log(i)
        into(i+5)
    }
    into(5)
}
multiply(50)
// Out:
// 5
// 10
// 15
// 20
// 25
// 30
// 35
// 40
// 45
// 50

// %%
function factorial(n){
    function incre(i){
        if(i>n)return 1
        return i*incre(i+1)
    }
    return incre(1)
}
console.log(factorial(5))
// Out:
// 16

// %%
function sumOfNatural(n){
    function incre(i){
        if(i>n)return 0
        return i+incre(i+1)
    }
    return incre(1)
}
let n=5
console.log(sumOfNatural(n))
// Out:
// 15

// %%
function fibonacciNumber(n){
    if(n === 0)return 0
    if(n === 1)return 1
    return fibonacciNumber(n-1)+fibonacciNumber(n-2)
}
let n=3
console.log(fibonacciNumber(n))
// Out:
// 2

// %%
function permutation(str){
    if(str.length <=1)return [str]
    let perms=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutation(res)){
            perms.push(char+j)
        }
    }
    return perms
}
let str="abc"
console.log(permutation(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
function permutation2(str){
    let perms=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutation2(res)){
            perms.push(char+j)
        }
    }
    return perms
}
let str='abc'
console.log(permutation2(str))
// Out:
// Stack trace:
// SyntaxError: Identifier 'permutation2' has already been declared
//     at <anonymous>:1:1

// %%
let permutation3=function(str){
    if(str.length<=1)return [str]
    let perms=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutation3(res)){
            perms.push(char+j)
        }
    }
    return perms
}
let str='abc'
console.log(permutation3(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
function subsequence(arr){
    let i=0
    while(i<=arr.length){
        let str=''
        for(let j=1;j<arr.length;j++){
            str+=j
        }
        console.log(str)
        i++
    }
    return arr
}
let arr=[1,2,3]
console.log(subsequence(arr))
// Out:
// 12
// 12
// 12
// 12
// [ 1, 2, 3 ]

// %%
function subsequence(arr){
    function sequence(seq=[],i=0){
        if(seq.length > 0){
            console.log(seq)
        }
        for(let j=i;j<arr.length;j++){
            seq.push(arr[j])
            sequence(seq,j+1)
            seq.pop()
        }
    }
    sequence()
}
let arr=[1,2,3]
subsequence(arr)
// Out:
// [ 1 ]
// [ 1, 2 ]
// [ 1, 2, 3 ]
// [ 1, 3 ]
// [ 2 ]
// [ 2, 3 ]
// [ 3 ]

// %%
function permutations(str){
    if(str.length <=1)return [str]
    let perm=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let seq=str.slice(0,i)+str.slice(i+1)
        for(let j of permutations(seq)){
            perm.push(char+j)
        }
    }
    return perm
}
let str='abc'
console.log(permutations(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
let permutationIV=function(str){
    if(str.length <=1)return [str]
    let perm=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutationIV(res)){
            perm.push(char+j)
        }
    }
    return perm
}
let str='abc'
console.log(permutationIV(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
function subSequence(arr){
    //if(arr.length <= 1)return arr
    function counter(jrr=[],i=0){
        if(jrr.length > 0)
        for(let j=i;j<arr.length;j++){
            jrr.push(arr[j])
            counter(jrr,j+1)
            jrr.pop()
        }
    }
    counter()
}
let arr=[1,2,3]
console.log(subSequence(arr))
// Out:
// undefined

// %%
let subSequence2=function(arr){
    function counter(seq=[],i=0){
        if(seq.length >= 1){
            console.log(seq)
        }
        for(let j=i;j<arr.length;j++){
            seq.push(arr[j])
            counter(seq,j+1)
            seq.pop()
        }
    }
    counter()
}
let arr=[1,2,3]
subSequence2(arr)
// Out:
// [ 1 ]
// [ 1, 2 ]
// [ 1, 2, 3 ]
// [ 1, 3 ]
// [ 2 ]
// [ 2, 3 ]
// [ 3 ]

// %%
function subSequence(arr){
    function sequence(jrr=[],i=0){
        if(jrr.length >= 1){
            console.log(jrr)
        }    
        for(let j=i;j<arr.length;j++){
            jrr.push(arr[j])
            sequence(jrr,j+1)
            jrr.pop()
        }
    }
    sequence()
}
let arr=[1,2,3]
console.log(subSequence(arr))
// Out:
// [ 1 ]
// [ 1, 2 ]
// [ 1, 2, 3 ]
// [ 1, 3 ]
// [ 2 ]
// [ 2, 3 ]
// [ 3 ]
// undefined

// %%
function subSequence(arr){
    function sequence(jrr=[],i=0){
        if(jrr.length >= 1)console.log(jrr)
        for(let j=i;j<arr.length;j++){
            jrr.push(arr[j])
            sequence(jrr,j+1)
            jrr.pop()
        }
    }
    sequence()
}
let arr=[1,2,3]
subSequence(arr)
// Out:
// [ 1 ]
// [ 1, 2 ]
// [ 1, 2, 3 ]
// [ 1, 3 ]
// [ 2 ]
// [ 2, 3 ]
// [ 3 ]

// %%
let permutation9=function(str){
    if(str.length <= 1)return [str]
    let perm=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutation9(res)){
            perm.push(char+j)
        }
    }
    return perm
}
let str='abc'
console.log(permutation9(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
let linkedListPAlindrome=function(head){
    let slow=head,fast=head,prev=null
    while(fast && fast.next){
        fast=fast.next.next
        let next=slow.next
        slow.next=prev
        prev=slow
        slow=next
    }
    if(fast)slow=slow.next
    while(prev && slow){
        if(prev.val !== slow.val)return false
        prev=prev.next
        slow=slow.next
    }
    return true
}

// %%
let reverseLinkedList=function(head){
    let temp=head,prev=null,next=null
    while(temp){
        next=temp.next
        temp.next=prev
        prev=temp
        temp=next
    }
    return prev
}

// %%
let intersectionofTwo=function(headA,headB){
    let A=headA,B=headB 
    while(A !== B){
        A=A?A.next:headB
        B=B?B.next:headA
    }
    return A
}

// %%
let deleteNode=function(node){
    if(node.next){
        node.val=node.next.val
        node.next=node.next.next
    }
}

// %%
let removeLinkedList=function(head,val){
    let newNode=new ListNode(0)
    newNode.next=head
    let current=newNode
    while(current.next){
        if(current.next.val === val){
            current.next=current.next.next
        }
        current=current.next
    }
    return newNode.next
}

// %%
let subSequenceI=function(arr){
    function sequence(jrr=[],i=0){
        if(jrr.length >= 1)console.log(jrr)
        for(let j=i;j<arr.length;j++){
           jrr.push(arr[j])
           sequence(jrr,j+1)
           jrr.pop()
        }
    }
    sequence()
}
let arr=[1,2,3]
subSequenceI(arr)
// Out:
// [ 1 ]
// [ 1, 2 ]
// [ 1, 2, 3 ]
// [ 1, 3 ]
// [ 2 ]
// [ 2, 3 ]
// [ 3 ]

// %%
let permutationX=function(str){
    if(str.length <= 1)return [str]
    let perm=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutationX(res)){
            perm.push(char+j)
        }
    }
    return perm
}
let str='abc'
console.log(permutationX(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
let subSequence7=function(arr){
    function seq3(jrr=[],i=0){
        if(jrr.length >=1)console.log(jrr)
        for(let j=i;j<arr.length;j++){
             jrr.push(arr[j])
             seq3(jrr,j+1)
             jrr.pop()
        }
    }
    seq3()
}
let arr=[1,2,3]
subSequence7(arr)
// Out:
// [ 1 ]
// [ 1, 2 ]
// [ 1, 2, 3 ]
// [ 1, 3 ]
// [ 2 ]
// [ 2, 3 ]
// [ 3 ]

// %%
let permutationV=function(str){
    if(str.length <= 1)return [str]
    let per=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutationV(res)){
            per.push(char+j)
        }
    }
    return per
}
let str="abc"
console.log(permutationV(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
function mergeSort(arr){
    if(arr.length <= 1)return arr
    let mid=Math.floor(arr.length/2)
    let left=mergeSort(arr.slice(0,mid))
    let right=mergeSort(arr.slice(mid))
    return merge(left,right)
}
function merge(left,right){
    let res=[]
    while(left.length && right.length){
        res.push(left[0]<right[0] ? left.shift() : right.shift())
    }
    return res.concat(left,right)
}
let arr=[5,1,3,2,4]
console.log(mergeSort(arr))
// Out:
// [ 5, 4, 3, 2, 1 ]

// %%
let mergeSort=function(arr){
    if(arr.length <=1)return arr
    let mid=Math.floor(arr.length/2)
    let left=mergeSort(arr.slice(0,mid))
    let right =mergeSort(arr.slice(mid))
    return sort(left,right)
}
function sort(left,right){
    let ans=[]
    while(left.length && right.length){
        ans.push(left[0]<right[0]?left.shift():right.shift())
    }
    return ans.concat(left,right)
}

// %%
function mergeSort(arr){
    if(arr.length <= 1)return arr
    let mid=Math.floor(arr.length/2)
    let left=mergeSort(arr.slice(0,mid))
    let right=mergeSort(arr.slice(mid))
    return sorted(left,right)
}
function sorted(left,right){
    let res=[]
    while(left.length && right.length){
        res.push(left[0]<right[0]?left.shift():right.shift())
    }
    return res.concat(left,right)
}
let arr=[4,1,3,5,2]
console.log(mergeSort(arr))
// Out:
// [ 5, 4, 3, 2, 1 ]

// %%
function mergeSort(arr){
    if(arr.length <= 1)return arr
    let mid=Math.floor(arr.length/2)
    let left=mergeSort(arr.slice(0,mid))
    let right=mergeSort(arr.slice(mid))
    return mergeS(left,right)
}
function mergeS(left,right){
    let res=[]
    while(left.length && right.length){
        res.push(left[0]<right[0]?left.shift():right.shift())
    }
    return res.concat(left,right)
}
let arr=[5,1,3,4,2]
console.log(mergeSort(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let mergeSortS=function(arr){
    if(arr.length <= 1)return arr
    let mid=Math.floor(arr.length/2)
    let left=mergeSortS(arr.slice(0,mid))
    let right=mergeSortS(arr.slice(mid))
    return sort(left,right)
}
function sort(left,right){
    let res=[]
    while(left.length && right.length){
        res.push(left[0] < right[0] ? left.shift() : right.shift())
    }
    return res.concat(left,right)
}
let arr=[5,1,3,4,2]
console.log(mergeSortS(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
let permutationB=function(str){
    if(str.length <= 1)return [str]
    let perm=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutationB(res)){
            perm.push(char+j)
        }
    }
    return perm
}
let str='abc'
console.log(permutationB(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
function sumOfNNaturalNumber(n){
    if(n <= 0) return 0
    return n + sumOfNNaturalNumber(n - 1)
}
let n = 5
console.log(sumOfNNaturalNumber(n))

// %%
function factorial(n) {
    if(n <= 0)return 1
    return n*factorial(n-1)    
}
let n=5
console.log(factorial(n))
// Out:
// 120

// %%
let fibonacciSeries=(n)=>{
    if(n===0)return 0
    if(n===1)return 1 
    return fibonacciSeries(n-1)+fibonacciSeries(n-2)
}
let n=2
console.log(fibonacciSeries(n))
// Out:
// 1

// %%
let permutationNV=function(str){
    if(str.length <= 1)return [str]
    let perm=[]
    for(let i=0;i<str.length;i++){
        let char=str[i]
        let res=str.slice(0,i)+str.slice(i+1)
        for(let j of permutationNV(res)){
            perm.push(char+j)
        }
    }
    return perm
}
let str='abc'
console.log(permutationNV(str))
// Out:
// [ "abc", "acb", "bac", "bca", "cab", "cba" ]

// %%
let subSequence89=function(arr){
    function sequence(jrr=[],i=0){
        if(jrr.length >=1)console.log(jrr)
        for(let j=i;j<arr.length;j++){
            jrr.push(arr[j])
            sequence(jrr,j+1)
            jrr.pop()
        }
    }
    sequence()
}
let arr=[1,2,3]
console.log(subSequence89(arr))
// Out:
// [ 1 ]
// [ 1, 2 ]
// [ 1, 2, 3 ]
// [ 1, 3 ]
// [ 2 ]
// [ 2, 3 ]
// [ 3 ]
// undefined

// %%
let mergeSortQ=function(arr){
    if(arr.length <=1)return arr
    let mid=Math.floor(arr.length/2)
    let left=mergeSortQ(arr.slice(0,mid))
    let right=mergeSortQ(arr.slice(mid))
    return merger(left,right)
}
function merger(left,right){
    let res=[]
    while(left.length && right.length){
        res.push(left[0] < right[0] ? left.shift() : right.shift())
    }
    return res.concat(left,right)
}
let arr=[5,1,3,2,4]
console.log(mergeSortQ(arr))
// Out:
// [ 1, 2, 3, 4, 5 ]

// %%
class Employee{
    constructor(name,salary){
        this.name=name
        this.salary=salary
    }
}
let e1=new Employee("Gaurav",12000)
let e2=new Employee("Saurav",21000)
let e3=new Employee("Manjot",31000)
let e4=new Employee("Shruti",32000)
let e5=new Employee("Anamika",29000)

let emp=[e1,e2,e3,e4,e5]
console.log(emp.sort((a,b)=>b.salary-a.salary))
// Out:
// [
//   Employee { name: "Shruti", salary: 32000 },
//   Employee { name: "Manjot", salary: 31000 },
//   Employee { name: "Anamika", salary: 29000 },
//   Employee { name: "Saurav", salary: 21000 },
//   Employee { name: "Gaurav", salary: 12000 }
// ]
